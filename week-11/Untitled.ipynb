# %%
#if you have not installed folium yet:
#!pip install folium

import folium
import pandas as pd

# %%
utah_df = pd.read_csv('1871-utah-postmaster-salaries.csv')
print(utah_df.sample(5))
utah_df.dtypes
# Out:
#        PO_Name  County State  PM_Salary   Latitude   Longitude
# 58   Kaysville   Davis    UT         70  41.035700 -111.935600
# 107  Santaquin    Utah    UT         93  39.976066 -111.784933
# 17   Coalville  Summit    UT         91  40.915781 -111.397697
# 61    Laketown    Utah    UT         12        NaN         NaN
# 67       Lynne   Weber    UT         27  41.223000 -111.973830
# PO_Name       object
# County        object
# State         object
# PM_Salary      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
utah_map_empty = folium.Map(location=[40, -111], zoom_start=6)
utah_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea5a723ffa043804b0427e5587f296da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea5a723ffa043804b0427e5587f296da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea5a723ffa043804b0427e5587f296da = L.map(
#                 &quot;map_ea5a723ffa043804b0427e5587f296da&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b0e8264e3493ceda28415fe0dec74f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b0e8264e3493ceda28415fe0dec74f2.addTo(map_ea5a723ffa043804b0427e5587f296da);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_empty_map():
    return folium.Map(location=[40, -111], zoom_start=6)

utah_map = create_empty_map()
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5920208a725007e4783a60f7ee73697 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5920208a725007e4783a60f7ee73697&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5920208a725007e4783a60f7ee73697 = L.map(
#                 &quot;map_c5920208a725007e4783a60f7ee73697&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0a457345b095ec1b36d69548b69f7d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0a457345b095ec1b36d69548b69f7d0.addTo(map_c5920208a725007e4783a60f7ee73697);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = utah_df.isna().sum()
print(missing_values)
# Out:
# PO_Name      0
# County       0
# State        0
# PM_Salary    0
# Latitude     4
# Longitude    4
# dtype: int64

# %%
# Filter out post offices that are missing a latitude value (ie. we don't have any location information about it)
utah_df_locations = utah_df[utah_df['Latitude'].notna()]
print(len(utah_df))
print(len(utah_df_locations))
# Out:
# 136
# 132

# %%
folium.Marker(location=[38.41, -112.339], popup="Adamsville Post Office").add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5920208a725007e4783a60f7ee73697 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5920208a725007e4783a60f7ee73697&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5920208a725007e4783a60f7ee73697 = L.map(
#                 &quot;map_c5920208a725007e4783a60f7ee73697&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0a457345b095ec1b36d69548b69f7d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0a457345b095ec1b36d69548b69f7d0.addTo(map_c5920208a725007e4783a60f7ee73697);
#
#
#             tile_layer_a0a457345b095ec1b36d69548b69f7d0.addTo(map_c5920208a725007e4783a60f7ee73697);
#
#
#             var marker_75e7376ae383d9e7e4f2b6e5a57866dd = L.marker(
#                 [38.41, -112.339],
#                 {
# }
#             ).addTo(map_c5920208a725007e4783a60f7ee73697);
#
#
#         var popup_eb7560d328dfc56c39d9147ecfec0b33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50e26fafcd31e3470f0ec1f7ce4d419b = $(`&lt;div id=&quot;html_50e26fafcd31e3470f0ec1f7ce4d419b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville Post Office&lt;/div&gt;`)[0];
#                 popup_eb7560d328dfc56c39d9147ecfec0b33.setContent(html_50e26fafcd31e3470f0ec1f7ce4d419b);
#
#
#
#         marker_75e7376ae383d9e7e4f2b6e5a57866dd.bindPopup(popup_eb7560d328dfc56c39d9147ecfec0b33)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)

# %%
#create a base empty map
utah_map = create_empty_map()

#generate a random row of data
sample_row = utah_df_locations.sample(1)

#use our function on the random row
create_map_markers(sample_row, utah_map)

#display the map
utah_map
# Out:
# C:\Users\Surface\anaconda3\Lib\site-packages\folium\utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# C:\Users\Surface\anaconda3\Lib\site-packages\folium\utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# C:\Users\Surface\anaconda3\Lib\site-packages\folium\utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41b0b91d00031684d26e1a946f329601 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41b0b91d00031684d26e1a946f329601&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41b0b91d00031684d26e1a946f329601 = L.map(
#                 &quot;map_41b0b91d00031684d26e1a946f329601&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a719551c469a967073988e626a7bb561 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a719551c469a967073988e626a7bb561.addTo(map_41b0b91d00031684d26e1a946f329601);
#
#
#             var marker_c3b01ec0dae9d7cea9613b1b8065ad68 = L.marker(
#                 [41.0685562, -111.5138141],
#                 {
# }
#             ).addTo(map_41b0b91d00031684d26e1a946f329601);
#
#
#         var popup_e100079dc0024f1ed3db7e0ac4348668 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a724af3be7e3e371eb1832711b84544 = $(`&lt;div id=&quot;html_7a724af3be7e3e371eb1832711b84544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20    Croydon Name: PO_Name, dtype: object&lt;/div&gt;`)[0];
#                 popup_e100079dc0024f1ed3db7e0ac4348668.setContent(html_7a724af3be7e3e371eb1832711b84544);
#
#
#
#         marker_c3b01ec0dae9d7cea9613b1b8065ad68.bindPopup(popup_e100079dc0024f1ed3db7e0ac4348668)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah_map)

utah_map
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_12776\2508161898.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Name of post office:", row[0])
# Name of post office: Adamsville
# Name of post office: Alma
# Name of post office: Alpine City
# Name of post office: American Fork
# Name of post office: Bellevue
# Name of post office: Bingham Canyon
# Name of post office: Brigham City
# Name of post office: Bullion
# Name of post office: Cedar City
# Name of post office: Cedar Valley
# Name of post office: Centerville
# Name of post office: Central City
# Name of post office: Chicken Creek
# Name of post office: Clarkston
# Name of post office: Clifton
# Name of post office: Clover Valley
# Name of post office: Coalville
# Name of post office: Corinne
# Name of post office: Cove Creek
# Name of post office: Croydon
# Name of post office: Deseret
# Name of post office: Diamond
# Name of post office: Draper
# Name of post office: Duncans Retreat
# Name of post office: Echo City
# Name of post office: Eden
# Name of post office: Emmaville
# Name of post office: Ephraim
# Name of post office: Eureka
# Name of post office: Fair View
# Name of post office: Fairfield
# Name of post office: Farmington
# Name of post office: Fillmore City
# Name of post office: Forest City
# Name of post office: Fort Hamblin
# Name of post office: Fountain Green
# Name of post office: Franklin
# Name of post office: Goshen
# Name of post office: Grafton
# Name of post office: Grantsville
# Name of post office: Gunnison
# Name of post office: Harrisburg
# Name of post office: Harrisville
# Name of post office: Heber
# Name of post office: Hebron
# Name of post office: Herriman
# Name of post office: Holden
# Name of post office: Hooper
# Name of post office: Huntsville
# Name of post office: Hyde Park
# Name of post office: Hyrum
# Name of post office: Iron City
# Name of post office: Johnson
# Name of post office: Kamas
# Name of post office: Kanab
# Name of post office: Kanarraville
# Name of post office: Kanosh
# Name of post office: Kaysville
# Name of post office: Kelton
# Name of post office: Lake Point
# Name of post office: Leeds
# Name of post office: Lehi City
# Name of post office: Levan
# Name of post office: Liberty
# Name of post office: Logan
# Name of post office: Lynne
# Name of post office: Manti
# Name of post office: Meadow
# Name of post office: Mendon
# Name of post office: Midway
# Name of post office: Mill Creek
# Name of post office: Millville
# Name of post office: Minersville
# Name of post office: Mona
# Name of post office: Monroe
# Name of post office: Morgan
# Name of post office: Moroni
# Name of post office: New Harmony
# Name of post office: Newton
# Name of post office: North Ogden
# Name of post office: Ogden City
# Name of post office: Ophir
# Name of post office: Paradise
# Name of post office: Paragonah
# Name of post office: Parowan
# Name of post office: Payson
# Name of post office: Peoa
# Name of post office: Petersburgh
# Name of post office: Peterson
# Name of post office: Pine Valley
# Name of post office: Pinto
# Name of post office: Plain City
# Name of post office: Pleasant Grove
# Name of post office: Portage
# Name of post office: Providence
# Name of post office: Provo City
# Name of post office: Richfield
# Name of post office: Richmond
# Name of post office: Riverdale
# Name of post office: Rockville
# Name of post office: Saint George
# Name of post office: Salina
# Name of post office: Salt Creek
# Name of post office: Salt Lake City
# Name of post office: Santaquin
# Name of post office: Scipio
# Name of post office: Silver City
# Name of post office: Slatersville
# Name of post office: Smithfield
# Name of post office: South Cottonwood
# Name of post office: Spanish Fork
# Name of post office: Spring City
# Name of post office: Springdale
# Name of post office: Springville
# Name of post office: Stockton
# Name of post office: Stoker
# Name of post office: Summit
# Name of post office: Tokersville
# Name of post office: Tooele
# Name of post office: Uintah
# Name of post office: Union
# Name of post office: Virgin City
# Name of post office: Wales
# Name of post office: Wallsburg
# Name of post office: Wanship
# Name of post office: Wasatch
# Name of post office: Washington
# Name of post office: Wellsville
# Name of post office: West Jordan
# Name of post office: Willard
# Name of post office: Winsor
# Name of post office: Woods Cross
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8779e33a51500573225993972e82eef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8779e33a51500573225993972e82eef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8779e33a51500573225993972e82eef = L.map(
#                 &quot;map_f8779e33a51500573225993972e82eef&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd45699b8f6f8d1da449d3c221649088 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd45699b8f6f8d1da449d3c221649088.addTo(map_f8779e33a51500573225993972e82eef);
#
#
#             var marker_0ff3aa581d14f89b2ca5a02d46ad3a8d = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_f8779e33a51500573225993972e82eef);
#
#
#         var popup_accec056d59be30810d7b08dc6341578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04c965d70c82f60775df39b1810b2c7a = $(`&lt;div id=&quot;html_04c965d70c82f60775df39b1810b2c7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_accec056d59be30810d7b08dc6341578.setContent(html_04c965d70c82f60775df39b1810b2c7a);
#
#
#
#         marker_0ff3aa581d14f89b2ca5a02d46ad3a8d.bindPopup(popup_accec056d59be30810d7b08dc6341578)
#         ;
#
#
#
#
#             var marker_133208f222f88c67a2b815e12e73c3a4 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_f8779e33a51500573225993972e82eef);
#
#
#         var popup_b025e2a4db4b68dffb3672bb29d5d0cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f50fcc518ba0b3c9affca91a5d2750 = $(`&lt;div id=&quot;html_01f50fcc518ba0b3c9affca91a5d2750&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_b025e2a4db4b68dffb3672bb29d5d0cc.setContent(html_01f50fcc518ba0b3c9affca91a5d2750);
#
#
#
#         marker_133208f222f88c67a2b815e12e73c3a4.bindPopup(popup_b025e2a4db4b68dffb3672bb29d5d0cc)
#         ;
#
#
#
#
#             var marker_09964c48c0b24b0a114db75e869254c7 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_f8779e33a51500573225993972e82eef);
#
#
#         var popup_c7b66ab7664ecd73303e180d03f30507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37ca55a9a30cb0291c83fb0791fe55e4 = $(`&lt;div id=&quot;html_37ca55a9a30cb0291c83fb0791fe55e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_c7b66ab7664ecd73303e180d03f30507.setContent(html_37ca55a9a30cb0291c83fb0791fe55e4);
#
#
#
#         marker_09964c48c0b24b0a114db75e869254c7.bindPopup(popup_c7b66ab7664ecd73303e180d03f30507)
#         ;
#
#
#
#
#             var marker_b95b2d3bb4fd212fb59870beba5be80c = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_f8779e33a51500573225993972e82eef);
#
#
#         var popup_4ca89f76cc14cc7e776ba129b1afdd19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ff0ef02318da3843fddc77b0282675d = $(`&lt;div id=&quot;html_6ff0ef02318da3843fddc77b0282675d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_4ca89f76cc14cc7e776ba129b1afdd19.setContent(html_6ff0ef02318da3843fddc77b0282675d);
#
#
#
#         marker_b95b2d3bb4fd212fb59870beba5be80c.bindPopup(popup_4ca89f76cc14cc7e776ba129b1afdd19)
#         ;
#
#
#
#
#             var marker_10c2fcca012bbfb7a51266c2630dee0b = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_f8779e33a51500573225993972e82eef);
#
#
#         var popup_d7fddc5639e0d38764e7149f7fe96ad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f399799d456c47d6eb0579ea1cca63dd = $(`&lt;div id=&quot;html_f399799d456c47d6eb0579ea1cca63dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_d7fddc5639e0d38764e7149f7fe96ad1.setContent(html_f399799d456c47d6eb0579ea1cca63dd);
#
#
#
#         marker_10c2fcca012bbfb7a51266c2630dee0b.bindPopup(popup_d7fddc5639e0d38764e7149f7fe96ad1)
#         ;
#
#
#
#
#             var marker_79eb8c551ab1879d3b158001eb4cf286 = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
utah_map = utah_map_empty

# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
utah_df_locations.apply(
    create_map_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea5a723ffa043804b0427e5587f296da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea5a723ffa043804b0427e5587f296da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea5a723ffa043804b0427e5587f296da = L.map(
#                 &quot;map_ea5a723ffa043804b0427e5587f296da&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b0e8264e3493ceda28415fe0dec74f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b0e8264e3493ceda28415fe0dec74f2.addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#             tile_layer_0b0e8264e3493ceda28415fe0dec74f2.addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#             var marker_511702ea211da0540f882ddb9082583a = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#         var popup_f9bd60a7246674451ab36afe63441859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e539eee72c9774b66fd32d80a18c6e1 = $(`&lt;div id=&quot;html_0e539eee72c9774b66fd32d80a18c6e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_f9bd60a7246674451ab36afe63441859.setContent(html_0e539eee72c9774b66fd32d80a18c6e1);
#
#
#
#         marker_511702ea211da0540f882ddb9082583a.bindPopup(popup_f9bd60a7246674451ab36afe63441859)
#         ;
#
#
#
#
#             var marker_5c268dc5cacfa73a920634f3716ae782 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#         var popup_4306724d3a573c984578c9d6a147faa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c2f19d773732f9c2d85103b7da1d0f5 = $(`&lt;div id=&quot;html_9c2f19d773732f9c2d85103b7da1d0f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_4306724d3a573c984578c9d6a147faa0.setContent(html_9c2f19d773732f9c2d85103b7da1d0f5);
#
#
#
#         marker_5c268dc5cacfa73a920634f3716ae782.bindPopup(popup_4306724d3a573c984578c9d6a147faa0)
#         ;
#
#
#
#
#             var marker_9be111f04c137717b0dad6c80c8009e4 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#         var popup_cf685db6b1190852f0c803637ba960eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f7bc18605b71753d0dcdc6d7924171a = $(`&lt;div id=&quot;html_5f7bc18605b71753d0dcdc6d7924171a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_cf685db6b1190852f0c803637ba960eb.setContent(html_5f7bc18605b71753d0dcdc6d7924171a);
#
#
#
#         marker_9be111f04c137717b0dad6c80c8009e4.bindPopup(popup_cf685db6b1190852f0c803637ba960eb)
#         ;
#
#
#
#
#             var marker_782174a7d92f77af48afa2bb26efe95f = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#         var popup_fc1be96f5228b1761a1a90b2d8ddc4f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15affef44ab8d4b7d38096df9ca623c8 = $(`&lt;div id=&quot;html_15affef44ab8d4b7d38096df9ca623c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_fc1be96f5228b1761a1a90b2d8ddc4f4.setContent(html_15affef44ab8d4b7d38096df9ca623c8);
#
#
#
#         marker_782174a7d92f77af48afa2bb26efe95f.bindPopup(popup_fc1be96f5228b1761a1a90b2d8ddc4f4)
#         ;
#
#
#
#
#             var marker_22620d4aff6d9f98e1092a65ea7b61d3 = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_ea5a723ffa043804b0427e5587f296da);
#
#
#         var popup_3a8bf368755cea9b4057b961fb60bc7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79c61d21570991bd13eea1faff36f693 = $(`&lt;div id=&quot;html_79c61d21570991bd13eea1faff36f693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_3a8bf368755cea9b4057b961fb60bc7b.setContent(html_79c61d21570991bd13eea1faff36f693);
#
#
#
#         marker_22620d4aff6d9f98e1092a65ea7b61d3.bindPopup(popup_3a8bf368755cea9b4057b961fb60bc7b)
#         ;
#
#
#
#
#             var

# %%
# Melanie Walsh function we will edit:
#def create_ICE_map_markers(row, map_name):
#    folium.CircleMarker(location=[row['lat'], row['lon']], raidus=100, fill=True,
#                       popup=folium.Popup(f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}", max_width=200),
#                       tooltip=f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}"
#                       ).add_to(map_name)

def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=200,
                       fill=True,
                       popup=folium.Popup(f"{row['PO_Name'].title()}", max_width=200),
                       tooltip=f"{row['PO_Name'].title()}"
                       ).add_to(map_name)

# %%
# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(create_circle_markers, map_name=utah_map, axis="columns")

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_961d2e89c7436c2ecb1f4e1b1fe3325a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_961d2e89c7436c2ecb1f4e1b1fe3325a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_961d2e89c7436c2ecb1f4e1b1fe3325a = L.map(
#                 &quot;map_961d2e89c7436c2ecb1f4e1b1fe3325a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03e5cfc9ea9fc9e6725e63dbf63ef4f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03e5cfc9ea9fc9e6725e63dbf63ef4f6.addTo(map_961d2e89c7436c2ecb1f4e1b1fe3325a);
#
#
#             var circle_marker_c876ddfa1e4047a75cb72dc12c74067f = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_961d2e89c7436c2ecb1f4e1b1fe3325a);
#
#
#         var popup_e743d6d18b39371184246baf6d05bba4 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_996513a5dbbcdf4d9f836860674e0c73 = $(`&lt;div id=&quot;html_996513a5dbbcdf4d9f836860674e0c73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_e743d6d18b39371184246baf6d05bba4.setContent(html_996513a5dbbcdf4d9f836860674e0c73);
#
#
#
#         circle_marker_c876ddfa1e4047a75cb72dc12c74067f.bindPopup(popup_e743d6d18b39371184246baf6d05bba4)
#         ;
#
#
#
#
#             circle_marker_c876ddfa1e4047a75cb72dc12c74067f.bindTooltip(
#                 `&lt;div&gt;
#                      Adamsville
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a1c676f340fa986b2a3090978c1aba06 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_961d2e89c7436c2ecb1f4e1b1fe3325a);
#
#
#         var popup_2713449f9f2021efdf7b818f88773465 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_955e61963bf3fbdf736325fabe4e3847 = $(`&lt;div id=&quot;html_955e61963bf3fbdf736325fabe4e3847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_2713449f9f2021efdf7b818f88773465.setContent(html_955e61963bf3fbdf736325fabe4e3847);
#
#
#
#         circle_marker_a1c676f340fa986b2a3090978c1aba06.bindPopup(popup_2713449f9f2021efdf7b818f88773465)
#         ;
#
#
#
#
#             circle_marker_a1c676f340fa986b2a3090978c1aba06.bindTooltip(
#                 `&lt;div&gt;
#                      Alma
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_36769526f6ec89994f7250bddb538af6 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_961d2e89c7436c2ecb1f4e1b1fe3325a);
#
#
#         var popup_42851666391a0202fe3d30eb07e23265 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_75c5d07d2dae8394bf4dd17a96fbdf20 = $(`&lt;div id=&quot;html_75c5d07d2dae8394bf4dd17a96fbdf20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_42851666391a0202fe3d30eb07e23265.setContent(html_75c5d07d2dae8394bf4dd17a96fbdf20);

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=14,
                       color='green',
                       fill=True,
                       fill_color='green',
                       fill_opacity=0.2,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00fdc734d3154fa91fa1ebdbc377af43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00fdc734d3154fa91fa1ebdbc377af43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00fdc734d3154fa91fa1ebdbc377af43 = L.map(
#                 &quot;map_00fdc734d3154fa91fa1ebdbc377af43&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73152e3cf2713086f18fa83a09c6e3cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73152e3cf2713086f18fa83a09c6e3cf.addTo(map_00fdc734d3154fa91fa1ebdbc377af43);
#
#
#             var circle_marker_5d725df2446581e1c36f05a9a37d9dfa = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00fdc734d3154fa91fa1ebdbc377af43);
#
#
#         var popup_aec84b3394e3b3d4f4e01e898a8375b1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_5e00b6030240974f82c2240a4905c650 = $(`&lt;div id=&quot;html_5e00b6030240974f82c2240a4905c650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_aec84b3394e3b3d4f4e01e898a8375b1.setContent(html_5e00b6030240974f82c2240a4905c650);
#
#
#
#         circle_marker_5d725df2446581e1c36f05a9a37d9dfa.bindPopup(popup_aec84b3394e3b3d4f4e01e898a8375b1)
#         ;
#
#
#
#
#             circle_marker_5d725df2446581e1c36f05a9a37d9dfa.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6e277fec41d936ca1ae3e533c9147520 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00fdc734d3154fa91fa1ebdbc377af43);
#
#
#         var popup_c4c84ab902a6b80e0103971b7a0f6a1c = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c2761f6e5b560b4fa3f0a1a1e7ddabc6 = $(`&lt;div id=&quot;html_c2761f6e5b560b4fa3f0a1a1e7ddabc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_c4c84ab902a6b80e0103971b7a0f6a1c.setContent(html_c2761f6e5b560b4fa3f0a1a1e7ddabc6);
#
#
#
#         circle_marker_6e277fec41d936ca1ae3e533c9147520.bindPopup(popup_c4c84ab902a6b80e0103971b7a0f6a1c)
#         ;
#
#
#
#
#             circle_marker_6e277fec41d936ca1ae3e533c9147520.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9fcd69ddf6cd1e3d092b4c6eac088405 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00fdc734d3154fa91fa1ebdbc377af43);
#
#
#         var popup_a56f1eb43bbc63feeb8b0d230fe41a79 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_ecc02234df85310bbf077f039b74376a = $(`&lt;div id=&quot;html_ecc02234df85310bbf077f039b74376a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_a56f1eb43bbc63feeb8b0d230fe41a79.setContent(html

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=8,
                       color='red',
                       fill=True,
                       fill_color='red',
                       fill_opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c90bdb87e5edce847773d59e55d11b86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c90bdb87e5edce847773d59e55d11b86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c90bdb87e5edce847773d59e55d11b86 = L.map(
#                 &quot;map_c90bdb87e5edce847773d59e55d11b86&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c159b91876332e0499b7e9637747fbbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c159b91876332e0499b7e9637747fbbf.addTo(map_c90bdb87e5edce847773d59e55d11b86);
#
#
#             var circle_marker_035ade969bdc3d1d6193fb16eeb40728 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c90bdb87e5edce847773d59e55d11b86);
#
#
#         var popup_8f8d6fdd7d7a582c0862363a1a757a44 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9f61c9030ebbad4b50a879a6962e1202 = $(`&lt;div id=&quot;html_9f61c9030ebbad4b50a879a6962e1202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_8f8d6fdd7d7a582c0862363a1a757a44.setContent(html_9f61c9030ebbad4b50a879a6962e1202);
#
#
#
#         circle_marker_035ade969bdc3d1d6193fb16eeb40728.bindPopup(popup_8f8d6fdd7d7a582c0862363a1a757a44)
#         ;
#
#
#
#
#             circle_marker_035ade969bdc3d1d6193fb16eeb40728.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7c6a65c6b26448859c2380bcc845fe1c = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c90bdb87e5edce847773d59e55d11b86);
#
#
#         var popup_7baf6417a4ce4a1233622f94be431da3 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4554ae404f9d139c91fc86556ad9069d = $(`&lt;div id=&quot;html_4554ae404f9d139c91fc86556ad9069d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_7baf6417a4ce4a1233622f94be431da3.setContent(html_4554ae404f9d139c91fc86556ad9069d);
#
#
#
#         circle_marker_7c6a65c6b26448859c2380bcc845fe1c.bindPopup(popup_7baf6417a4ce4a1233622f94be431da3)
#         ;
#
#
#
#
#             circle_marker_7c6a65c6b26448859c2380bcc845fe1c.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c67154d7ba392ea684aaa19e2be22aca = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c90bdb87e5edce847773d59e55d11b86);
#
#
#         var popup_0740df0710f4c60d96ce981a11cbd7e5 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_71f8bb821d55332a74554d44e1efd70b = $(`&lt;div id=&quot;html_71f8bb821d55332a74554d44e1efd70b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_0740df0710f4c60d96ce981a11cbd7e5.setContent(html_71f8bb821d5533

# %%
# make new function to create circle markers sized by postmaster salary
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary'],
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df62bf018280e1eb9ae3bf98565e26f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df62bf018280e1eb9ae3bf98565e26f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df62bf018280e1eb9ae3bf98565e26f5 = L.map(
#                 &quot;map_df62bf018280e1eb9ae3bf98565e26f5&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b148b1cb99e3ec40e85e3374f1d2852 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b148b1cb99e3ec40e85e3374f1d2852.addTo(map_df62bf018280e1eb9ae3bf98565e26f5);
#
#
#             var circle_marker_2ef53389f1b12ebe8d430281ed3007dc = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df62bf018280e1eb9ae3bf98565e26f5);
#
#
#         var popup_8e87505afe7c50260465996e6d62a3c9 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_aae62f658cdf9a67f7462853b53cde3d = $(`&lt;div id=&quot;html_aae62f658cdf9a67f7462853b53cde3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_8e87505afe7c50260465996e6d62a3c9.setContent(html_aae62f658cdf9a67f7462853b53cde3d);
#
#
#
#         circle_marker_2ef53389f1b12ebe8d430281ed3007dc.bindPopup(popup_8e87505afe7c50260465996e6d62a3c9)
#         ;
#
#
#
#
#             circle_marker_2ef53389f1b12ebe8d430281ed3007dc.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_55d7736b9fc85da6da7b41b568c6a5a8 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df62bf018280e1eb9ae3bf98565e26f5);
#
#
#         var popup_c799fd42dbc754d71962951a14a795c3 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4a1767cc91a121a47cf05b0661e18e10 = $(`&lt;div id=&quot;html_4a1767cc91a121a47cf05b0661e18e10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_c799fd42dbc754d71962951a14a795c3.setContent(html_4a1767cc91a121a47cf05b0661e18e10);
#
#
#
#         circle_marker_55d7736b9fc85da6da7b41b568c6a5a8.bindPopup(popup_c799fd42dbc754d71962951a14a795c3)
#         ;
#
#
#
#
#             circle_marker_55d7736b9fc85da6da7b41b568c6a5a8.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_0b2c01c6f281d128c8a219feadc46a89 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df62bf018280e1eb9ae3bf98565e26f5);
#
#
#         var popup_57a4e22e5248e5772736af6e982e9eec = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_317a592da255a3565713428b2a5c47a8 = $(`&lt;div id=&quot;html_317a592da255a3565713428b2a5c47a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_57a4e22e5248e5772736af6e982e9eec.set

# %%
# make new function to create circle markers sized by postmaster salary - this time adjusting the radius size in pixels to make it more legible
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary']/100,
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e49fcadf969f4fbd7ff988fab269c6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e49fcadf969f4fbd7ff988fab269c6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e49fcadf969f4fbd7ff988fab269c6f = L.map(
#                 &quot;map_9e49fcadf969f4fbd7ff988fab269c6f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac284a52df5d3054c4c933de89822768 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac284a52df5d3054c4c933de89822768.addTo(map_9e49fcadf969f4fbd7ff988fab269c6f);
#
#
#             var circle_marker_e745cfcfc25e92d972e295d38e3c93a1 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e49fcadf969f4fbd7ff988fab269c6f);
#
#
#         var popup_f9e4fdc526ca7cfb041503a51c2d8e3c = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9d11ba0c3a91175dbddfa9ffafe58015 = $(`&lt;div id=&quot;html_9d11ba0c3a91175dbddfa9ffafe58015&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_f9e4fdc526ca7cfb041503a51c2d8e3c.setContent(html_9d11ba0c3a91175dbddfa9ffafe58015);
#
#
#
#         circle_marker_e745cfcfc25e92d972e295d38e3c93a1.bindPopup(popup_f9e4fdc526ca7cfb041503a51c2d8e3c)
#         ;
#
#
#
#
#             circle_marker_e745cfcfc25e92d972e295d38e3c93a1.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8a093383abaf243b2e9db07181b2999a = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e49fcadf969f4fbd7ff988fab269c6f);
#
#
#         var popup_8b9ee358a5004c16ca3ef8704616f30c = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c45c5cceeea08a50520514e422af2599 = $(`&lt;div id=&quot;html_c45c5cceeea08a50520514e422af2599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_8b9ee358a5004c16ca3ef8704616f30c.setContent(html_c45c5cceeea08a50520514e422af2599);
#
#
#
#         circle_marker_8a093383abaf243b2e9db07181b2999a.bindPopup(popup_8b9ee358a5004c16ca3ef8704616f30c)
#         ;
#
#
#
#
#             circle_marker_8a093383abaf243b2e9db07181b2999a.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_915e8dc453f0b6323a7950503d0475fe = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e49fcadf969f4fbd7ff988fab269c6f);
#
#
#         var popup_9f95fe0179280e1627b34cc1589fae1d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_5cf1f2f952d9084589c70b022719fafe = $(`&lt;div id=&quot;html_5cf1f2f952d9084589c70b022719fafe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_9f95fe0179280e1627b34cc1589fae1

# %%
utah_df_locations.describe()
# Out:
#          PM_Salary    Latitude   Longitude
# count   132.000000  132.000000  132.000000
# mean    101.098485   39.907743 -112.161190
# std     344.225580    1.505091    0.593117
# min       4.000000   37.006375 -113.819415
# 25%      12.000000   38.874099 -112.379230
# 50%      22.000000   40.380926 -111.973830
# 75%      70.000000   41.080917 -111.819912
# max    3600.000000   42.187500 -111.281850

# %%
def add_salary_buckets(salary):
    # Create a new column for the salary bucket
    if salary < 50:
        bucket = 'Low Salary'
    elif salary >= 50 and salary < 250:
        bucket = 'Medium Salary'
    elif salary >= 250 and salary < 1000:
        bucket = 'High Salary'
    else:
        bucket = 'Very High Salary'
    return bucket

# %%
#test out the function
add_salary_buckets(2000)
# Out:
# 'Very High Salary'

# %%
utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
utah_df_locations.head()
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_12776\2959544325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
#          PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0     Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1           Alma       Weber    UT         12  41.248833 -112.078275
# 2    Alpine City        Utah    UT         27  40.453283 -111.777986
# 3  American Fork        Utah    UT        130  40.375229 -111.796320
# 4       Bellevue  Washington    UT         20  37.340815 -113.274116
#
#    Salary_Bucket
# 0     Low Salary
# 1     Low Salary
# 2     Low Salary
# 3  Medium Salary
# 4     Low Salary

# %%
# create a function to add marker sizes based on the salary bucket
def add_marker_sizes(category):
    if category == 'Low Salary':
        return 4
    elif category == 'Medium Salary':
        return 8
    elif category == 'High Salary':
        return 12
    else:
        return 16

#test out the function
add_marker_sizes('High Salary')
# Out:
# 12

# %%
utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
utah_df_locations.head(10)
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_12776\3689819186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
#            PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0       Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1             Alma       Weber    UT         12  41.248833 -112.078275
# 2      Alpine City        Utah    UT         27  40.453283 -111.777986
# 3    American Fork        Utah    UT        130  40.375229 -111.796320
# 4         Bellevue  Washington    UT         20  37.340815 -113.274116
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# 7     Brigham City   Box Elder    UT        400  41.510213 -112.015501
# 8          Bullion       Piute    UT         12  38.410000 -112.339000
# 9       Cedar City        Iron    UT        200  37.676644 -113.057171
# 10    Cedar Valley        Utah    UT         13  40.327171 -112.104385
#
#     Salary_Bucket  Marker_Size
# 0      Low Salary            4
# 1      Low Salary            4
# 2      Low Salary            4
# 3   Medium Salary            8
# 4      Low Salary            4
# 5      Low Salary            4
# 7     High Salary           12
# 8      Low Salary            4
# 9   Medium Salary            8
# 10     Low Salary            4

# %%
# make new function to create circle markers sized by salary category
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['Marker_Size'],
                       fill=True,
                       opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96a221980d2d70f8ac3049f49a81c89f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96a221980d2d70f8ac3049f49a81c89f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96a221980d2d70f8ac3049f49a81c89f = L.map(
#                 &quot;map_96a221980d2d70f8ac3049f49a81c89f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_447cd5b9612e12f39168c83367403e22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_447cd5b9612e12f39168c83367403e22.addTo(map_96a221980d2d70f8ac3049f49a81c89f);
#
#
#             var circle_marker_2b31828b63278b6d378dc2ae8d33beb2 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a221980d2d70f8ac3049f49a81c89f);
#
#
#         var popup_33f2c769a4e0f85d894d691de4ba2564 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b27e5919b565770db530eeff7b33c4cf = $(`&lt;div id=&quot;html_b27e5919b565770db530eeff7b33c4cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_33f2c769a4e0f85d894d691de4ba2564.setContent(html_b27e5919b565770db530eeff7b33c4cf);
#
#
#
#         circle_marker_2b31828b63278b6d378dc2ae8d33beb2.bindPopup(popup_33f2c769a4e0f85d894d691de4ba2564)
#         ;
#
#
#
#
#             circle_marker_2b31828b63278b6d378dc2ae8d33beb2.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7b1fbc1aa202971ad9774343d3094f0c = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a221980d2d70f8ac3049f49a81c89f);
#
#
#         var popup_9c15f619dee54500d193dd1ae9f17cd4 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_683ddfb8b514a0b477598130db1868e5 = $(`&lt;div id=&quot;html_683ddfb8b514a0b477598130db1868e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_9c15f619dee54500d193dd1ae9f17cd4.setContent(html_683ddfb8b514a0b477598130db1868e5);
#
#
#
#         circle_marker_7b1fbc1aa202971ad9774343d3094f0c.bindPopup(popup_9c15f619dee54500d193dd1ae9f17cd4)
#         ;
#
#
#
#
#             circle_marker_7b1fbc1aa202971ad9774343d3094f0c.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ff520cdf51cb70f08ea76af24a1e3d67 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a221980d2d70f8ac3049f49a81c89f);
#
#
#         var popup_970d804c2fd8d049ae1bd2017c317bd0 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_e84d9825adcc17a640591a46920d368b = $(`&lt;div id=&quot;html_e84d9825adcc17a640591a46920d368b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_970d804c2fd8d049ae1bd2017c317bd0.setCon

# %%
utah2_df = pd.read_csv('1877-official-register.csv')
print(utah2_df.sample(5))
utah2_df.dtypes
# Out:
#               Name State                  Department  \
# 122        Olympia    WA  Department of the Interior
# 781       Portland    OR              War Department
# 786       Prescott    AZ              War Department
# 472         Helena    MT         Treasury Department
# 467  San Francisco    CA         Treasury Department
#
#                                              Type  People   Latitude  \
# 122  Governors and Secretaries of the Territories       2  47.037874
# 781                             Paymasters Clerks       5  45.523062
# 786                             Paymasters Clerks       1  34.540024
# 472                               Customs Service       2  46.588371
# 467                               Customs Service     211  37.774929
#
#       Longitude
# 122 -122.900695
# 781 -122.676482
# 786 -112.468503
# 472 -112.024505
# 467 -122.419416
# Name           object
# State          object
# Department     object
# Type           object
# People          int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row[0]).add_to(map_name)

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah2_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah2_map)

utah2_map
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_12776\1356760799.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(row[0])
# C:\Users\Surface\AppData\Local\Temp\ipykernel_12776\984466012.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row[0]).add_to(map_name)
# Adamsville
# Alma
# Alpine City
# American Fork
# Bellevue
# Bingham Canyon
# Brigham City
# Bullion
# Cedar City
# Cedar Valley
# Centerville
# Central City
# Chicken Creek
# Clarkston
# Clifton
# Clover Valley
# Coalville
# Corinne
# Cove Creek
# Croydon
# Deseret
# Diamond
# Draper
# Duncans Retreat
# Echo City
# Eden
# Emmaville
# Ephraim
# Eureka
# Fair View
# Fairfield
# Farmington
# Fillmore City
# Forest City
# Fort Hamblin
# Fountain Green
# Franklin
# Goshen
# Grafton
# Grantsville
# Gunnison
# Harrisburg
# Harrisville
# Heber
# Hebron
# Herriman
# Holden
# Hooper
# Huntsville
# Hyde Park
# Hyrum
# Iron City
# Johnson
# Kamas
# Kanab
# Kanarraville
# Kanosh
# Kaysville
# Kelton
# Lake Point
# Leeds
# Lehi City
# Levan
# Liberty
# Logan
# Lynne
# Manti
# Meadow
# Mendon
# Midway
# Mill Creek
# Millville
# Minersville
# Mona
# Monroe
# Morgan
# Moroni
# New Harmony
# Newton
# North Ogden
# Ogden City
# Ophir
# Paradise
# Paragonah
# Parowan
# Payson
# Peoa
# Petersburgh
# Peterson
# Pine Valley
# Pinto
# Plain City
# Pleasant Grove
# Portage
# Providence
# Provo City
# Richfield
# Richmond
# Riverdale
# Rockville
# Saint George
# Salina
# Salt Creek
# Salt Lake City
# Santaquin
# Scipio
# Silver City
# Slatersville
# Smithfield
# South Cottonwood
# Spanish Fork
# Spring City
# Springdale
# Springville
# Stockton
# Stoker
# Summit
# Tokersville
# Tooele
# Uintah
# Union
# Virgin City
# Wales
# Wallsburg
# Wanship
# Wasatch
# Washington
# Wellsville
# West Jordan
# Willard
# Winsor
# Woods Cross
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c55112743be7c05b00972b7f58bbb86f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c55112743be7c05b00972b7f58bbb86f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c55112743be7c05b00972b7f58bbb86f = L.map(
#                 &quot;map_c55112743be7c05b00972b7f58bbb86f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f615ec210673ed049e72fe846f22043 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f615ec210673ed049e72fe846f22043.addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#             var marker_6308d0a666767083827d7908660ce136 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#         var popup_c8c99ff7c04db9a9bde876c24bd93bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fdef03a85eb9dead83c3f2ab74ded25 = $(`&lt;div id=&quot;html_7fdef03a85eb9dead83c3f2ab74ded25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_c8c99ff7c04db9a9bde876c24bd93bf9.setContent(html_7fdef03a85eb9dead83c3f2ab74ded25);
#
#
#
#         marker_6308d0a666767083827d7908660ce136.bindPopup(popup_c8c99ff7c04db9a9bde876c24bd93bf9)
#         ;
#
#
#
#
#             var marker_60fb52ca9eb0e03bf980dd1ac8c16581 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#         var popup_2b97e202de2ac8b26c02f88e0bb17dc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25c6bb3e70cd6b228c492b4f2b4896ce = $(`&lt;div id=&quot;html_25c6bb3e70cd6b228c492b4f2b4896ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_2b97e202de2ac8b26c02f88e0bb17dc4.setContent(html_25c6bb3e70cd6b228c492b4f2b4896ce);
#
#
#
#         marker_60fb52ca9eb0e03bf980dd1ac8c16581.bindPopup(popup_2b97e202de2ac8b26c02f88e0bb17dc4)
#         ;
#
#
#
#
#             var marker_89dd93ba7d47081f91170a75990b70b8 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#         var popup_10fcf3f54bf731565c032331f76b410e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7366e8a169a25eb295d097a51e9ba1ce = $(`&lt;div id=&quot;html_7366e8a169a25eb295d097a51e9ba1ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_10fcf3f54bf731565c032331f76b410e.setContent(html_7366e8a169a25eb295d097a51e9ba1ce);
#
#
#
#         marker_89dd93ba7d47081f91170a75990b70b8.bindPopup(popup_10fcf3f54bf731565c032331f76b410e)
#         ;
#
#
#
#
#             var marker_dea3248638cadc0acc916cc7163e9bb6 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#         var popup_eb92c3584e8ab69c19500285d50712ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0218705edfc8524913e3ac5605919c23 = $(`&lt;div id=&quot;html_0218705edfc8524913e3ac5605919c23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_eb92c3584e8ab69c19500285d50712ed.setContent(html_0218705edfc8524913e3ac5605919c23);
#
#
#
#         marker_dea3248638cadc0acc916cc7163e9bb6.bindPopup(popup_eb92c3584e8ab69c19500285d50712ed)
#         ;
#
#
#
#
#             var marker_9f74e43a21abe04e3a3f4265a684aa79 = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_c55112743be7c05b00972b7f58bbb86f);
#
#
#         var popup_b01e62aa10cab0ee5bd30caf0a0d9b10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f86cee83659c3e478f0a6d7a1e716d9 = $(`&lt;div id=&quot;html_2f86cee83659c3e478f0a6d7a1e716d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_b01e62aa10cab0ee5bd30caf0a0d9b10.setContent(html_2f86cee83659c3e478f0a6d7a1e716d9);
#
#
#
#         marker_9f74e43a21abe04e3a3f4265a684aa79.bindPopup(popup_b01e62aa10cab0ee5bd30caf0a0d9b10)
#         ;
#
#
#
#
#             var marker_955b84826f77b2889cd5dd45a145b27a = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }
